# %%
"""Path bootstrap for lab notebooks.

Resolves the repo root (where `app/`, `scripts/`, `data/` live) regardless of
where Jupyter was launched from. Used by all 4 notebooks:

    import _setup  # noqa: F401   -- adds repo root to sys.path

Why: `sys.path.insert(0, "../scripts")` is cwd-relative and silently breaks
when the notebook runs from CI or a different working directory. `__file__`
is stable; cwd is not.
"""
from __future__ import annotations

# %%
import sys
from pathlib import Path

# %%
_REPO_ROOT = Path(__file__).resolve().parent.parent
if str(_REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(_REPO_ROOT))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 _REPO_ROOT = Path(__file__).resolve().parent.parent
#       2 if str(_REPO_ROOT) not in sys.path:
#       3     sys.path.insert(0, str(_REPO_ROOT))
#
# NameError: name '__file__' is not defined

# %%
# Load environment variables automatically for all notebooks
try:
    from dotenv import load_dotenv
    load_dotenv(dotenv_path=_REPO_ROOT / ".env")
except ImportError:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # Load environment variables automatically for all notebooks
#       2 try:
#       3     from dotenv import load_dotenv
#       4     load_dotenv(dotenv_path=_REPO_ROOT / ".env")
# ----> 5 except ImportError:
#       6     pass
#
# NameError: name '_REPO_ROOT' is not defined
